# %% [markdown]
# # 🐼 PANDAS

# %% [markdown]
# **Excel -> Pandas , Worksheet->Data frame ,Column->Series ,Row Heading->Index,Row->Row,EmptyCell->NaN**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Creating a dataframe from an array

# %% [markdown]
# OPTION 1

# %%
#creating an array
data=np.array([[1,4],[2,5],[3,6]])

# %%
#creating a dataframe
df=pd.DataFrame(data, index=['row1','row2','row3'], columns=['col1','col2'])

# %%
#showing the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# OPTION 2

# %%
#creating an array with list shape
data=[[1,4],[2,5],[3,6]]

# %%
#creating a dataframe
df=pd.DataFrame(data, index=['row1','row2','row3'], columns=['col1','col2'])

# %%
#showing the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# # Creating a dataframe from a dictionary

# %%
#lists used for this example
states=["california","texas","florida","New York"]
population=[39883993,3383929,2839382,38393984]

# %%
#storing lists within a dictionary 
dict_states={"States":states,"Population":population}

# %%
#Creating a data frame
df_population=pd.DataFrame(dict_states)

# %%
df_population
# Out:
#        States  Population
# 0  california    39883993
# 1       texas     3383929
# 2     florida     2839382
# 3    New York    38393984

# %% [markdown]
# # Creating dataframe from a csv file

# %%
#reading the csv file
df_exams=pd.read_csv("StudentsPerformance.csv")

# %%
#showing the first 5 rows
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#show the first 5 rows in a dataframe
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#show the last 5 rows in a dataframe
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# show the first n rows in a dataframe
df_exams.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
# show the las n rows in a dataframe
df_exams.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
 #getting acces to the number of rows and columns
df_exams.shape
# Out:
# (1000, 8)

# %%
#display all rows change the default behaviour of pandas
pd.set_option("display.max_rows",1000)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [raw]
# Attributes-A value associated with an object(referenced by name using dotted experssions) like df.columns
# Function-A group of related statements that perform a specific task.
# eg)Python built in functions like len(),max(),min()
# Methods-A function which is defined inside a class body
# df.head()

# %% [markdown]
# # # Attributes

# %%
#getting access to the shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
#getting the access to the index attribute
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#getting access to the column attribute
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#getting the data types of each column
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# # # Methods

# %%
#showing the first 5 columns
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#showing the info of the dataframe
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
#describing the basic statistics of the dataframe
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# ## Functions

# %%
#obtaining the length of the dataframe(number of rows)
len(df_exams)
# Out:
# 1000

# %%
#obtaining the highest index of the dataframe
max(df_exams.index)
# Out:
# 999

# %%
#obtaining the lowest index of the dataframe
min(df_exams.index)
# Out:
# 0

# %%
#obtaining the data type
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
# rounding the values of the dataset
# round(df_exams,2)  #this wont work for this example much

# %% [markdown]
# # 1.Selecting one column

# %% [markdown]
# **Syntax 1**

# %%
#select a column with [](preffered way to select a column)
# df_exams["gender"]

# %%
#check out the data type of a column
type(df_exams["gender"])
# Out:
# pandas.core.series.Series

# %%
#series:attributes and methods
df_exams["gender"].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %% [markdown]
# **Syntax 2**

# %%
#select a column with .
# df_exams.gender

# %%
# select a column with . {pitfalls}
df_exams.math score             #we need to put _ underscore
# Out:
#   Cell In[55], line 2
#     df_exams.math score
#                   ^
# SyntaxError: invalid syntax

# %%
#select the same column using []
df_exams["math score"]
# Out:
# 0       72
# 1       69
# 2       90
# 3       47
# 4       76
# 5       71
# 6       88
# 7       40
# 8       64
# 9       38
# 10      58
# 11      40
# 12      65
# 13      78
# 14      50
# 15      69
# 16      88
# 17      18
# 18      46
# 19      54
# 20      66
# 21      65
# 22      44
# 23      69
# 24      74
# 25      73
# 26      69
# 27      67
# 28      70
# 29      62
# 30      69
# 31      63
# 32      56
# 33      40
# 34      97
# 35      81
# 36      74
# 37      50
# 38      75
# 39      57
# 40      55
# 41      58
# 42      53
# 43      59
# 44      50
# 45      65
# 46      55
# 47      66
# 48      57
# 49      82
# 50      53
# 51      77
# 52      53
# 53      88
# 54      71
# 55      33
# 56      82
# 57      52
# 58      58
# 59       0
# 60      79
# 61      39
# 62      62
# 63      69
# 64      59
# 65      67
# 66      45
# 67      60
# 68      61
# 69      39
# 70      58
# 71      63
# 72      41
# 73      61
# 74      49
# 75      44
# ...

# %% [markdown]
# # 2 Select 2 or more columns

# %%
#select 2 columns using [[]]
df_exams[["gender","math score"]]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# 5    female          71
# 6    female          88
# 7      male          40
# 8      male          64
# 9    female          38
# 10     male          58
# 11     male          40
# 12   female          65
# 13     male          78
# 14   female          50
# 15   female          69
# 16     male          88
# 17   female          18
# 18     male          46
# 19   female          54
# 20     male          66
# 21   female          65
# 22     male          44
# 23   female          69
# 24     male          74
# 25     male          73
# 26     male          69
# 27   female          67
# 28     male          70
# 29   female          62
# 30   female          69
# 31   female          63
# 32   female          56
# 33     male          40
# 34     male          97
# 35     male          81
# 36   female          74
# ...

# %%
type(df_exams[["gender","math score"]])   #Any thing with [[]]
# Out:
# pandas.core.frame.DataFrame

# %%
#select 2 or more columns using[[]]
df_exams[["gender","writing score","math score","reading score"]]
# Out:
#      gender  writing score  math score  reading score
# 0    female             74          72             72
# 1    female             88          69             90
# 2    female             93          90             95
# 3      male             44          47             57
# 4      male             75          76             78
# 5    female             78          71             83
# 6    female             92          88             95
# 7      male             39          40             43
# 8      male             67          64             64
# 9    female             50          38             60
# 10     male             52          58             54
# 11     male             43          40             52
# 12   female             73          65             81
# 13     male             70          78             72
# 14   female             58          50             53
# 15   female             78          69             75
# ...

# %%
# We can't select2 or more columns with the "."

# %% [markdown]
# # Adding a new column

# %% [markdown]
# # # 1.1 Adding a new column with a scalar value

# %%
#adding a new column to the dataframe
df_exams["language score"]=70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [markdown]
# # # 1.2 Adding a new column with an array

# %% [raw]
# The dataframe has 1000 rows so we need to create an array of 1000 elements

# %%
#import numpy
import numpy as np

# %%
# create an array of 1000 elements
language_score=np.arange(0,1000)

# %%
#length of the array
len(language_score)
# Out:
# 1000

# %%
#adding a new column to dataframe with an array
df_exams["language score"]=language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
#create random integer numbers between 1 and 100
int_language_score=np.random.randint(1,100,size=1000)

# %%
# min value inclusive and high value exclusive
max(int_language_score)
min(int_language_score)
# Out:
# np.int32(1)

# %%
#adding a new column in the dataframe
df_exams["language_score"]=int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
#create a random float numbers between 1 and 100
np.random.uniform(0,100,size=100)
# Out:
# array([91.59121741, 49.21399568, 69.26994856, 78.09845546, 33.90924923,
#        21.74998886, 39.16173919, 75.44152601, 52.47214111, 63.74548587,
#        59.79972382, 43.0834695 , 56.9994002 , 99.96444705, 64.61460821,
#        57.33444356,  3.54331915, 61.01971775, 70.36585772, 83.98280719,
#        11.69006403, 31.96898135, 90.08393132, 10.02191326,  6.19604927,
#        24.55399036, 26.45355916, 35.41672367, 75.50013733, 68.12230705,
#        46.4433037 , 46.98213579, 95.51166263, 26.87939264, 39.00382955,
#        29.99986251, 74.4752612 , 51.30830542, 92.87240143, 72.56162025,
#        53.33900878, 21.5551445 , 74.53291876,  0.32751514, 13.50242506,
#        29.63942605, 70.43651475, 58.85331129, 84.69329143, 29.99320134,
#        22.51944672,  9.69568604, 70.28949288, 35.14058673,  3.02472036,
#        19.51129668, 68.26821651,  2.88388776, 26.48882976, 37.02931133,
#        66.89126639, 44.56938186, 94.31449712, 26.15447044, 79.55173208,
# ...

# %% [markdown]
# # # Adding a new Column

# %% [markdown]
# # assign()

# %% [markdown]
# When to use assign? 1)Add multiple columns in a single line of code.                                      2)when you need to overwrite the values of an existing columns(best practice)

# %%
import numpy as np

# %%
#create random numbers for our new score columns
score1=np.random.randint(1,100,size=1000)
score2=np.random.randint(1,100,size=1000)

# %%
#using assign() to add multiple columns
series1=pd.Series(score1, index=np.arange(0,1000))
series2=pd.Series(score2, index=np.arange(0,1000))

# %%
#using assign() to add multiple columns
df_exams=df_exams.assign(score1=series1,score2=series2)

# %% [markdown]
# # insert()

# %%
df_exams.insert(1, "math_score", series1)

# %%
df_exams
# Out:
#      gender  math_score  test race/ethnicity parental level of education  \
# 0    female          13    50        group B           bachelor's degree
# 1    female          49    98        group C                some college
# 2    female          25    41        group B             master's degree
# 3      male          33    23        group A          associate's degree
# 4      male          36    98        group C                some college
# ..      ...         ...   ...            ...                         ...
# 995  female          96    52        group E             master's degree
# 996    male          39     5        group C                 high school
# 997  female           7    58        group C                 high school
# 998  female          27    56        group D                some college
# 999  female          93    62        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# ...
